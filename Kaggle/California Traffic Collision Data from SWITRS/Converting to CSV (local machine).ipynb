# %%
import numpy as np
import pandas as pd
import sqlite3
import dask.dataframe as ddf
import matplotlib.pyplot as plt
import seaborn as sns

# plt.style.use("classic")
# %matplotlib inline
sns.set_style('darkgrid')

# %%
db = sqlite3.connect('switrs.sqlite')
cur = db.cursor()
date_threshold = "2016-01-01"

tables = [name[0] for name in cur.execute("SELECT name FROM sqlite_master")]
tables = ['collisions', 'parties']
df = {}

# %%
# Read collisions table
cmd = \
    "SELECT c.*\
        ,p.drivers_using_phone\
        ,p.drivers_on_drugs\
        ,p.parties_not_safe\
    FROM collisions c\
    LEFT JOIN\
        (SELECT case_id\
                ,SUM(CASE WHEN party_type='driver' THEN cellphone_in_use END) AS drivers_using_phone\
                ,SUM(CASE WHEN party_type='driver' AND party_drug_physical='under drug influence' THEN 1\
                            ELSE 0\
                        END) AS drivers_on_drugs\
                ,SUM(CASE WHEN party_safety_equipment_1 IN ('air bag deployed') OR\
                            party_safety_equipment_2 IN ('air bag deployed')\
                    THEN 0\
                    WHEN party_safety_equipment_1 IN ('lap/shoulder harness used','lap belt used','shoulder harness used') OR\
                            party_safety_equipment_2 IN ('lap/shoulder harness used','lap belt used','shoulder harness used')\
                    THEN 0.5\
                    ELSE 1\
                    END) AS parties_not_safe\
        FROM parties\
        GROUP BY case_id) p\
    ON c.case_id = p.case_id\
    WHERE c.collision_date>='{}'".format(date_threshold)
collisions = pd.read_sql_query(cmd, db)
# names = list(map(lambda x: x[0], cur.description))
# collisions = pd.DataFrame([list(x) for x in cur.execute(cmd)], columns=names+['drivers_using_phone','drivers_on_drugs', 'parties_not_safe'])

# Display
display(collisions.head())
collisions.info()
# Out:
#    case_id  jurisdiction officer_id reporting_district chp_shift  \
# 0  0081715        1941.0      11342                212   not chp
# 1  0726202        3600.0       8945                064   not chp
# 2  6292799        1942.0      41054               0729   not chp
# 3  6292800        1942.0      40164               1415   not chp
# 4  6292881        1602.0       1484                 50   not chp
#
#         population county_city_location county_location special_condition  \
# 0          >250000                 1941     los angeles                 0
# 1  50000 to 100000                 3612  san bernardino                 0
# 2          >250000                 1942     los angeles                 0
# 3          >250000                 1942     los angeles                 0
# 4   25000 to 50000                 1602           kings                 0
#
#   beat_type  ... primary_ramp secondary_ramp  latitude  longitude  \
# 0   not chp  ...         None           None       NaN        NaN
# 1   not chp  ...         None           None       NaN        NaN
# 2   not chp  ...         None           None       NaN        NaN
# 3   not chp  ...         None           None       NaN        NaN
# 4   not chp  ...         None           None  36.34256 -119.62345
#
#   collision_date collision_time  process_date drivers_using_phone  \
# 0     2020-03-14       07:45:00    2020-06-22                 0.0
# 1     2020-07-26       02:50:00    2020-09-30                 NaN
# 2     2016-03-11       11:30:00    2018-09-25                 0.0
# 3     2016-04-13       05:15:00    2018-09-27                 0.0
# 4     2017-08-31       01:07:00    2019-04-05                 0.0
#
#    drivers_on_drugs parties_not_safe
# 0                 0              0.5
# 1                 0              1.0
# 2                 1              1.5
# 3                 0              1.5
# 4                 1              1.0
#
# [5 rows x 78 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2429886 entries, 0 to 2429885
# Data columns (total 78 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_id                          object
#  1   jurisdiction                     float64
#  2   officer_id                       object
#  3   reporting_district               object
#  4   chp_shift                        object
#  5   population                       object
#  6   county_city_location             object
#  7   county_location                  object
#  8   special_condition                object
#  9   beat_type                        object
#  10  chp_beat_type                    object
#  11  city_division_lapd               object
#  12  chp_beat_class                   object
#  13  beat_number                      object
#  14  primary_road                     object
#  15  secondary_road                   object
#  16  distance                         float64
#  17  direction                        object
#  18  intersection                     float64
#  19  weather_1                        object
#  20  weather_2                        object
#  21  state_highway_indicator          float64
#  22  caltrans_county                  object
#  23  caltrans_district                float64
#  24  state_route                      float64
#  25  route_suffix                     object
#  26  postmile_prefix                  object
#  27  postmile                         float64
#  28  location_type                    object
#  29  ramp_intersection                object
#  30  side_of_highway                  object
#  31  tow_away                         float64
#  32  collision_severity               object
#  33  killed_victims                   int64
#  34  injured_victims                  int64
#  35  party_count                      float64
#  36  primary_collision_factor         object
#  37  pcf_violation_code               object
#  38  pcf_violation_category           object
#  39  pcf_violation                    float64
#  40  pcf_violation_subsection         object
#  41  hit_and_run                      object
#  42  type_of_collision                object
#  43  motor_vehicle_involved_with      object
#  44  pedestrian_action                object
#  45  road_surface                     object
#  46  road_condition_1                 object
#  47  road_condition_2                 object
#  48  lighting                         object
#  49  control_device                   object
#  50  chp_road_type                    object
#  51  pedestrian_collision             int64
#  52  bicycle_collision                int64
#  53  motorcycle_collision             int64
#  54  truck_collision                  int64
#  55  not_private_property             float64
#  56  alcohol_involved                 float64
#  57  statewide_vehicle_type_at_fault  object
#  58  chp_vehicle_type_at_fault        object
#  59  severe_injury_count              int64
#  60  other_visible_injury_count       int64
#  61  complaint_of_pain_injury_count   int64
#  62  pedestrian_killed_count          int64
#  63  pedestrian_injured_count         int64
#  64  bicyclist_killed_count           int64
#  65  bicyclist_injured_count          int64
#  66  motorcyclist_killed_count        int64
#  67  motorcyclist_injured_count       float64
#  68  primary_ramp                     object
#  69  secondary_ramp                   object
#  70  latitude                         float64
#  71  longitude                        float64
#  72  collision_date                   object
#  73  collision_time                   object
#  74  process_date                     object
#  75  drivers_using_phone              float64
#  76  drivers_on_drugs                 int64
#  77  parties_not_safe                 float64
# dtypes: float64(17), int64(15), object(46)
# memory usage: 1.4+ GB

# %%
# Alcohol Drugs involved
def alcohol_drugs_involved(df):
    alcohol = df['alcohol_involved']
    drugs = df['drivers_on_drugs']
    
    if alcohol==1 or drugs>0:
        return 1
    else:
        return 0

# Get hour from datetime
def hour(time):
    days, seconds = time.days, time.seconds
    return days * 24 + seconds // 3600

# Get part of day from collision time
def part_of_day(hour):
    if hour>=6 and hour<12:
        return 'Morning'
    elif hour>=12 and hour<17:
        return 'Afternoon'
    elif hour>=17 and hour<20:
        return 'Evening'
    elif hour>=20 and hour<6:
        return 'Night'

# Is caused by condition
def is_bc_condition(df):
    return 0;

# Is caused by human error
def is_bc_human_error(df):
    return 0;

# Is caused by violation
def is_bc_violation(df):
    return 0;

# Adding columns from date
collisions["collision_date"] = pd.to_datetime(collisions["collision_date"])
collisions["collision_year_month"] = collisions["collision_date"].dt.to_period('M')
collisions["collision_year"] = collisions["collision_date"].dt.year
collisions["collision_month"] = collisions["collision_date"].dt.month
collisions['collision_time'] = pd.to_timedelta(collisions['collision_time'])
collisions["collision_hour"] = collisions['collision_time'].apply(lambda x: hour(x))
collisions["collision_dow"] = collisions["collision_date"].dt.day_of_week
collisions["collision_day_name"] = collisions["collision_date"].dt.day_name()
collisions['has_injured'] = collisions['injured_victims'].apply(lambda x: 1 if x>0 else 0)
collisions['killed_victims'] = collisions['killed_victims'].astype(np.float)
collisions['is_fatal'] = np.array([1 if x > 0 else 0 for x in collisions['killed_victims']])
collisions['alcohol_involved'] = collisions['alcohol_involved'].apply(lambda x: 1 if x==1 else 0)
collisions['alcohol_drugs_involved'] = collisions[['alcohol_involved','drivers_on_drugs']].apply(alcohol_drugs_involved, axis=1)
collisions['part_of_day'] = collisions['collision_hour'].apply(lambda x: part_of_day(x))
# collisions['is_bc_condition'] = collisions[['road_surface','weather_1','weather_2']].apply(part_of_day)
# collisions['is_bc_human_error'] = collisions[['pcf_violation_category','','']].apply(is_bc_human_error)
collisions.head()

# Display
display(collisions.head())
display(collisions.info())

# Save as CSV
collisions.to_csv("collisions.csv")
del collisions
# Out:
# <ipython-input-10-88868cd865dc>:37: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   collisions['killed_victims'] = collisions['killed_victims'].astype(np.float)
#    case_id  jurisdiction officer_id reporting_district chp_shift  \
# 0  0081715        1941.0      11342                212   not chp
# 1  0726202        3600.0       8945                064   not chp
# 2  6292799        1942.0      41054               0729   not chp
# 3  6292800        1942.0      40164               1415   not chp
# 4  6292881        1602.0       1484                 50   not chp
#
#         population county_city_location county_location special_condition  \
# 0          >250000                 1941     los angeles                 0
# 1  50000 to 100000                 3612  san bernardino                 0
# 2          >250000                 1942     los angeles                 0
# 3          >250000                 1942     los angeles                 0
# 4   25000 to 50000                 1602           kings                 0
#
#   beat_type  ... collision_year_month collision_year collision_month  \
# 0   not chp  ...              2020-03           2020               3
# 1   not chp  ...              2020-07           2020               7
# 2   not chp  ...              2016-03           2016               3
# 3   not chp  ...              2016-04           2016               4
# 4   not chp  ...              2017-08           2017               8
#
#   collision_hour collision_dow collision_day_name  has_injured is_fatal  \
# 0            7.0             5           Saturday            0        0
# 1            2.0             6             Sunday            0        0
# 2           11.0             4             Friday            0        1
# 3            5.0             2          Wednesday            0        1
# 4            1.0             3           Thursday            1        1
#
#    alcohol_drugs_involved part_of_day
# 0                       0     Morning
# 1                       0        None
# 2                       1     Morning
# 3                       0        None
# 4                       1        None
#
# [5 rows x 88 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2429886 entries, 0 to 2429885
# Data columns (total 88 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_id                          object
#  1   jurisdiction                     float64
#  2   officer_id                       object
#  3   reporting_district               object
#  4   chp_shift                        object
#  5   population                       object
#  6   county_city_location             object
#  7   county_location                  object
#  8   special_condition                object
#  9   beat_type                        object
#  10  chp_beat_type                    object
#  11  city_division_lapd               object
#  12  chp_beat_class                   object
#  13  beat_number                      object
#  14  primary_road                     object
#  15  secondary_road                   object
#  16  distance                         float64
#  17  direction                        object
#  18  intersection                     float64
#  19  weather_1                        object
#  20  weather_2                        object
#  21  state_highway_indicator          float64
#  22  caltrans_county                  object
#  23  caltrans_district                float64
#  24  state_route                      float64
#  25  route_suffix                     object
#  26  postmile_prefix                  object
#  27  postmile                         float64
#  28  location_type                    object
#  29  ramp_intersection                object
#  30  side_of_highway                  object
#  31  tow_away                         float64
#  32  collision_severity               object
#  33  killed_victims                   float64
#  34  injured_victims                  int64
#  35  party_count                      float64
#  36  primary_collision_factor         object
#  37  pcf_violation_code               object
#  38  pcf_violation_category           object
#  39  pcf_violation                    float64
#  40  pcf_violation_subsection         object
#  41  hit_and_run                      object
#  42  type_of_collision                object
#  43  motor_vehicle_involved_with      object
#  44  pedestrian_action                object
#  45  road_surface                     object
#  46  road_condition_1                 object
#  47  road_condition_2                 object
#  48  lighting                         object
#  49  control_device                   object
#  50  chp_road_type                    object
#  51  pedestrian_collision             int64
#  52  bicycle_collision                int64
#  53  motorcycle_collision             int64
#  54  truck_collision                  int64
#  55  not_private_property             float64
#  56  alcohol_involved                 int64
#  57  statewide_vehicle_type_at_fault  object
#  58  chp_vehicle_type_at_fault        object
#  59  severe_injury_count              int64
#  60  other_visible_injury_count       int64
#  61  complaint_of_pain_injury_count   int64
#  62  pedestrian_killed_count          int64
#  63  pedestrian_injured_count         int64
#  64  bicyclist_killed_count           int64
#  65  bicyclist_injured_count          int64
#  66  motorcyclist_killed_count        int64
#  67  motorcyclist_injured_count       float64
#  68  primary_ramp                     object
#  69  secondary_ramp                   object
#  70  latitude                         float64
#  71  longitude                        float64
#  72  collision_date                   datetime64[ns]
#  73  collision_time                   timedelta64[ns]
#  74  process_date                     object
#  75  drivers_using_phone              float64
#  76  drivers_on_drugs                 int64
#  77  parties_not_safe                 float64
#  78  collision_year_month             period[M]
#  79  collision_year                   int64
#  80  collision_month                  int64
#  81  collision_hour                   float64
#  82  collision_dow                    int64
#  83  collision_day_name               object
#  84  has_injured                      int64
#  85  is_fatal                         int32
#  86  alcohol_drugs_involved           int64
#  87  part_of_day                      object
# dtypes: datetime64[ns](1), float64(18), int32(1), int64(20), object(46), period[M](1), timedelta64[ns](1)
# memory usage: 1.6+ GB
# None

# %%
# Read collisions table
cmd = "SELECT *\
        FROM parties p\
        LEFT JOIN \
            (SELECT case_id, collision_date\
            FROM collisions) c\
        ON p.case_id = c.case_id\
        WHERE collision_date>='{}'".format(date_threshold)
parties = pd.read_sql_query(cmd, db)

# %%
# Get age bucket
def party_age_bucket(age):
    if age<16:
        return '<16'
    elif age<25:
        return '16-24'
    elif age<35:
        return '25-34'
    elif age<45:
        return '35-44'
    elif age<55:
        return '45-54'
    elif age<65:
        return '55-64'
    elif age>=65:
        return '65+'
    else:
        return ''

parties["party_age_bucket"] = parties["party_age"].apply(lambda x: party_age_bucket(x))

# Display
parties.to_csv('parties.csv',index=False)
display(parties.head())
parties.info()
# Out:
#         id  case_id  party_number party_type  at_fault party_sex  party_age  \
# 0        1  0081715             1     driver         1    female       35.0
# 1        2  0081715             2     driver         0    female       43.0
# 2        3  0726202             1     driver         1      None        NaN
# 3  3846789  6292799             1     driver         0      male       44.0
# 4  3846790  6292799             2     driver         1      male       41.0
#
#           party_sobriety   party_drug_physical direction_of_travel  ...  \
# 0         not applicable        not applicable               north  ...
# 1         not applicable        not applicable               north  ...
# 2     impairment unknown                     G               north  ...
# 3  had not been drinking                  None                west  ...
# 4                   None  under drug influence                east  ...
#
#   movement_preceding_collision vehicle_year vehicle_make  \
# 0          proceeding straight       2007.0         ford
# 1          proceeding straight       2019.0         None
# 2          proceeding straight       2005.0         None
# 3             making left turn       2015.0    chevrolet
# 4          proceeding straight       2005.0     kawasaki
#
#    statewide_vehicle_type  chp_vehicle_type_towing chp_vehicle_type_towed  \
# 0                    None                     None                   None
# 1                    None                     None                   None
# 2           passenger car   passenger car, station                   None
# 3           passenger car   passenger car, station                   None
# 4   motorcycle or scooter               motorcycle                   None
#
#    party_race  case_id collision_date party_age_bucket
# 0       other  0081715     2020-03-14            35-44
# 1    hispanic  0081715     2020-03-14            35-44
# 2        None  0726202     2020-07-26
# 3       black  6292799     2016-03-11            35-44
# 4       white  6292799     2016-03-11            35-44
#
# [5 rows x 35 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4836559 entries, 0 to 4836558
# Data columns (total 35 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   case_id                       object
#  2   party_number                  int64
#  3   party_type                    object
#  4   at_fault                      int64
#  5   party_sex                     object
#  6   party_age                     float64
#  7   party_sobriety                object
#  8   party_drug_physical           object
#  9   direction_of_travel           object
#  10  party_safety_equipment_1      object
#  11  party_safety_equipment_2      object
#  12  financial_responsibility      object
#  13  hazardous_materials           float64
#  14  cellphone_in_use              float64
#  15  cellphone_use_type            object
#  16  school_bus_related            float64
#  17  oaf_violation_code            object
#  18  oaf_violation_category        object
#  19  oaf_violation_section         object
#  20  oaf_violation_suffix          object
#  21  other_associate_factor_1      object
#  22  other_associate_factor_2      object
#  23  party_number_killed           int64
#  24  party_number_injured          int64
#  25  movement_preceding_collision  object
#  26  vehicle_year                  float64
#  27  vehicle_make                  object
#  28  statewide_vehicle_type        object
#  29  chp_vehicle_type_towing       object
#  30  chp_vehicle_type_towed        object
#  31  party_race                    object
#  32  case_id                       object
#  33  collision_date                object
#  34  party_age_bucket              object
# dtypes: float64(5), int64(5), object(25)
# memory usage: 1.3+ GB
